# %%
import pandas as pd
import matplotlib.pyplot as plt
# import numpy as np

# %%
# define filename of data
fn_measurement = '1738335290.1606264-sdr-samples.csv'
fn_bits = '../data/can_bits.csv'

# load CSV 
df_maes = pd.read_csv(fn_measurement, delimiter=';', header=None)
df_bits = pd.read_csv(fn_bits, delimiter=';', header=None)

# %%
df_maes.head()
# Out:
#               0          1
# 0  1.738335e+09 -45.120504
# 1  1.738335e+09 -45.120504
# 2  1.738335e+09 -33.981070
# 3  1.738335e+09 -45.120504
# 4  1.738335e+09 -45.120504

# %%
df_bits.head()
# Out:
#               0  1
# 0  1.738335e+09  0
# 1  1.738335e+09  0
# 2  1.738335e+09  1
# 3  1.738335e+09  0
# 4  1.738335e+09  0

# %%
plt.plot(df_maes[0], df_maes[1])
plt.plot(df_bits[0], df_bits[1])

# %%
idxa = 2100
idxb = 2200

plt.figure(figsize=(12, 6))
plt.plot(df_maes[idxa:idxb][0], df_maes[idxa:idxb][1])
plt.plot(df_bits[0], df_bits[1]*8-45)
plt.show()
